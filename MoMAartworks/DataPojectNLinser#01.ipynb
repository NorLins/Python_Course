# %% [markdown]
# #MoMA's Artwork accquisition
# ##Data project for "Tools and Methods"-Seminar. Fall/Winter 2021/2021
#
# 1. First Idea was Social Network Analysis
# The first idea for this project was to use the dataset provided by the Museum of Modern Art New York on github to create a social netword analysis. Based on shared coauthorship of artworks within the collections. The following steps where undertaken to invest the dataset. A littel spoiler alert, the data provided on the artworks only shows the one artist that was involved in the creation of the artworks. Even when there are multiple. Therefore it is not possible to see which artists worked together.

# %%
#Setting up the working environment
import pandas as pd

# %%
#Import the file from github
artworksAll = pd.read_csv("/Users/linsernora/Pyhton_Course/Python_CourseNorLins/MoMAartworks/Artworks.csv")
artworksAll.head(15)
# Out:
#                                                 Title  \
# 0   Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1   City of Music, National Superior Conservatory ...
# 2   Villa near Vienna Project, Outside Vienna, Aus...
# 3   The Manhattan Transcripts Project, New York, N...
# 4   Villa, project, outside Vienna, Austria, Exter...
# 5   The Manhattan Transcripts Project, New York, N...
# 6   The Manhattan Transcripts Project, New York, N...
# 7   The Manhattan Transcripts Project, New York, N...
# 8   The Manhattan Transcripts Project, New York, N...
# 9   The Manhattan Transcripts Project, New York, N...
# 10  The Manhattan Transcripts Project, New York, N...
# 11  The Manhattan Transcripts Project, New York, N...
# 12  The Manhattan Transcripts Project, New York, N...
# 13  The Manhattan Transcripts Project, New York, N...
# 14  The Manhattan Transcripts Project, New York, N...
#
#                       Artist ConstituentID  \
# 0                Otto Wagner          6210
# ...

# %%
#investing the artist column
print(artworksAll["Artist"].head(130))
# Out:
# 0                   Otto Wagner
# 1      Christian de Portzamparc
# 2                    Emil Hoppe
# 3               Bernard Tschumi
# 4                    Emil Hoppe
#                  ...
# 125            Erich Mendelsohn
# 126                 Steven Holl
# 127            Erich Mendelsohn
# 128                 Steven Holl
# 129            Erich Mendelsohn
# Name: Artist, Length: 130, dtype: object

# %% [markdown]
# 2. Cealing up the data

# %%
list(artworksAll.columns.values)
# Out:
# ['Title',
#  'Artist',
#  'ConstituentID',
#  'ArtistBio',
#  'Nationality',
#  'BeginDate',
#  'EndDate',
#  'Gender',
#  'Date',
#  'Medium',
#  'Dimensions',
#  'CreditLine',
#  'AccessionNumber',
#  'Classification',
#  'Department',
#  'DateAcquired',
#  'Cataloged',
#  'ObjectID',
#  'URL',
#  'ThumbnailURL',
#  'Circumference (cm)',
#  'Depth (cm)',
#  'Diameter (cm)',
#  'Height (cm)',
#  'Length (cm)',
#  'Weight (kg)',
#  'Width (cm)',
#  'Seat Height (cm)',
#  'Duration (sec.)']

# %%
#finding our if there are artworks with more than one artist and if yes how they are separeted. 
#wrong approach:
#separator = (",")
#multiartists = [multiartists.append for separator in artworks["Artists"]]

# %%
artists = artworks["Artist"]
artists.isin([","])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 138146    False
# 138147    False
# 138148    False
# 138149    False
# 138150    False
# Name: Artist, Length: 138151, dtype: bool

# %% [markdown]
# Seems like there are no objects with more than one artist? Is that possible? The export only contains one occurrence linked artists that where part of the creation of to the object.
#
# Let's see if the artworks are listed multiple times to diplay multiple creators.

# %%
objectIds = artworks["ObjectID"]
artworks[objectIds.isin(objectIds[objectIds.duplicated()])]
# Out:
# Empty DataFrame
# Columns: [Title, Artist, ConstituentID, Gender, ObjectID]
# Index: []

# %% [markdown]
# There are also no duplicate ObjectIds, so each object is listed only once.
# Take a step back and take another look at the original file.

# %%
regex1 = r'([arto]+)\s{1}([0-9]+)[:]{1}([,A-ZÄÖÜa-zäöüß0-9.\s]+)[,\s]*([=\-\(\)\sA-ZÄÖÜa-zäöüß0-9]*)'

# %% [markdown]
# Due to the dataset we can not establish a social network analysis. New topic is therefore the accquisition history of MoMA artworks.
#
# 2. Accquisition history
# We want to invest the accquisition history of the Museum of Modern Art. Of spcial interest is the distribution of artworks from female or male ar
